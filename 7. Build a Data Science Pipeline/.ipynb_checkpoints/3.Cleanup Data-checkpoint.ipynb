# %%
# !pip install pandas

# %%
import os 
import pandas as pd

# %%
cwd = os.getcwd()
DIR_NAM = os.path.dirname(os.getcwd())
BASE_DIR = os.path.join(DIR_NAM,'7. Build a Data Science Pipeline')
DATA_DIR = os.path.join(BASE_DIR,'data')
CACHE_DIR = os.path.join(BASE_DIR,'cache')
os.makedirs(CACHE_DIR,exist_ok=True)

# %%
my_data = os.path.join(DATA_DIR,'2019.csv')
df = pd.read_csv(my_data)
df
# Out:
#      Rank                                      Release Group       Worldwide  \
# 0       1                                  Avengers: Endgame  $2,797,501,328
# 1       2                                      The Lion King  $1,656,943,394
# 2       3                                          Frozen II  $1,450,026,933
# 3       4                          Spider-Man: Far from Home  $1,131,927,996
# 4       5                                     Captain Marvel  $1,128,274,794
# ..    ...                                                ...             ...
# 195   196                               An Officer and a Spy     $18,878,658
# 196   197  Crayon Shin-chan: Honeymoon Hurricane - The Lo...     $18,738,951
# 197   198                                              Greta     $18,653,107
# 198   199                  Peppa Celebrates Chinese New Year     $18,653,040
# 199   200                                    Black Christmas     $18,529,730
#
# ...

# %%
df['Year'] = 2019

# %%
my_dataframe = []
csv_files = [x.replace('.csv','') for x in os.listdir(DATA_DIR) if x.endswith('.csv')]
csv_files.sort(reverse = True)
print(csv_files)
for filename in csv_files:
    year = filename
    csv_path = os.path.join(DATA_DIR,filename +'.csv')
    this_df = pd.read_csv(csv_path)
    this_df['filename'] = filename + '.csv'
    this_df['year'] = year
    my_dataframe.append(this_df)
# Out:
# ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000']

# %%
my_entire_dataframe = pd.concat(my_dataframe)
my_entire_dataframe.head()
# Out:
#    Rank          Release Group     Worldwide      Domestic      %  \
# 0     1                Hi, Mom  $822,009,764             -      -
# 1     2      F9: The Fast Saga  $714,400,845  $172,933,845  24.2%
# 2     3  Detective Chinatown 3  $686,257,563             -      -
# 3     4      Godzilla vs. Kong  $467,863,133  $100,563,133  21.5%
# 4     5            Black Widow  $377,689,901  $183,201,994  48.5%
#
#         Foreign    %.1  filename  year
# 0  $822,009,764   100%  2021.csv  2021
# 1  $541,467,000  75.8%  2021.csv  2021
# 2  $686,257,563   100%  2021.csv  2021
# 3  $367,300,000  78.5%  2021.csv  2021
# 4  $194,487,907  51.5%  2021.csv  2021

# %%
dataset = os.path.join(CACHE_DIR,'movies-box-office-dataset.csv')
my_entire_dataframe.to_csv(dataset,index= False)
